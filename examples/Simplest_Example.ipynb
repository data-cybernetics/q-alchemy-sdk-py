# %% [markdown]
# Needed dependencies:
#
#   * q-alchemy-sdk-py
#   * jupyter
#   * scikit-learn

# %%
import numpy as np
from sklearn.datasets import fetch_openml

from q_alchemy.initialize import q_alchemy_as_qasm

# %%
mnist = fetch_openml('mnist_784', version=1, parser="auto")

zero: np.ndarray = mnist.data[mnist.target == "0"].iloc[0].to_numpy()
filler = np.empty(2 ** 10 - zero.shape[0])
filler.fill(0)

zero = np.hstack([zero, filler])
zero = zero / np.linalg.norm(zero)

# %%
qasm, summary = q_alchemy_as_qasm(zero, max_fidelity_loss=0.2, api_key="<your api key>", return_summary=True)
len(qasm)
# Out:
# 77149

# %%
summary
# Out:
# {'fidelity_loss': 0.1987242255420667,
#  'min_fidelity': 0.8,
#  'circuit_depth': 495,
#  'circuit_ops': {'rz': 2247, 'rx': 1498, 'cx': 266, 'ry': 5},
#  'n_qubits': 10,
#  'status': 'OK'}

# %%
print(qasm)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[10];
# ry(0.010887183926535548) q[0];
# ry(0.1240010498675507) q[1];
# ry(0.1287123009938189) q[4];
# cx q[4],q[3];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(3.147196741167009) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(4.185653914736145) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(3.1465295618651745) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(-0.17511098792259716) q[4];
# rx(pi/2) q[4];
# rz(pi) q[4];
# rx(pi/2) q[4];
# rz(9.599888948691977) q[4];
# rz(1.4521098561002592) q[4];
# rx(pi/2) q[4];
# rz(5.8764088675720245) q[4];
# rx(pi/2) q[4];
# rz(7.724862116404605) q[4];
# ry(0.06548019129022331) q[5];
# cx q[0],q[6];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(3.1465677995276415) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(-0.46364760900080704) q[0];
# rx(pi/2) q[0];
# rz(pi) q[0];
# rx(pi/2) q[0];
# rz(9.888425569770185) q[0];
# rz(1.499933552765409) q[0];
# rx(pi/2) q[0];
# rz(5.110206159983244) q[0];
# rx(pi/2) q[0];
# rz(10.81436183372647) q[0];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(3.1441885567448185) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(3.53645547716518) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# ry(0.009069276798455811) q[7];
# cx q[7],q[2];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(3.152491659740616) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(-0.16513118360858137) q[2];
# rx(pi/2) q[2];
# rz(pi) q[2];
# rx(pi/2) q[2];
# rz(9.589909144377959) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(3.5556414451149774) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# cx q[2],q[4];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.333722088446294) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# cx q[2],q[4];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.293987898669954) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# cx q[2],q[4];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(3.3478941340465926) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(-2.0043610118671538) q[2];
# rx(pi/2) q[2];
# rz(5.83545105098292) q[2];
# rx(pi/2) q[2];
# rz(7.379541442782145) q[2];
# rz(1.963281377768764) q[4];
# rx(pi/2) q[4];
# rz(5.088346473835236) q[4];
# rx(pi/2) q[4];
# rz(11.146411796701688) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(5.702377346438717) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(3.145974598425011) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(12.29544234164927) q[7];
# cx q[5],q[8];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(3.1476251134461) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(0.23863435071364458) q[5];
# rx(pi/2) q[5];
# rz(pi) q[5];
# rx(pi/2) q[5];
# rz(9.186143610055733) q[5];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(3.91384127116936) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# cx q[5],q[0];
# rz(1.6745410063068933) q[0];
# rx(pi/2) q[0];
# rz(4.71009085340891) q[0];
# rx(pi/2) q[0];
# rz(7.898238199804047) q[0];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(6.185232502443409) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# cx q[5],q[0];
# rz(-1.8056894419110083) q[0];
# rx(pi/2) q[0];
# rz(5.869281072896546) q[0];
# rx(pi/2) q[0];
# rz(7.638287347707587) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(4.297894985111431) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(5.521398128610898) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(3.909279945962446) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(3.142001990878311) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(1.5678051996037272) q[8];
# rx(pi/2) q[8];
# rz(5.1161262242727465) q[8];
# rx(pi/2) q[8];
# rz(10.987960647266664) q[8];
# cx q[6],q[8];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(5.210021620014567) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# rz(2.7592676287814735) q[8];
# rx(pi/2) q[8];
# rz(4.434913547894003) q[8];
# rx(pi/2) q[8];
# rz(8.261544104543601) q[8];
# cx q[6],q[8];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(5.163159371449998) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(4.843053472232432) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# rz(-0.19825635999397662) q[8];
# rx(pi/2) q[8];
# rz(5.14437728188049) q[8];
# rx(pi/2) q[8];
# rz(8.977393308094392) q[8];
# rz(2.719334087252081) q[8];
# rx(pi/2) q[8];
# rz(5.001034627106465) q[8];
# rx(pi/2) q[8];
# rz(9.29757781944023) q[8];
# cx q[1],q[9];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(3.1472530860967396) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(4.285169922076232) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# cx q[7],q[1];
# rz(2.870065967629138) q[1];
# rx(pi/2) q[1];
# rz(4.388128184224267) q[1];
# rx(pi/2) q[1];
# rz(8.278152991147655) q[1];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(5.405387931920865) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[1];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.901406859291311) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(11.65039741227645) q[1];
# cx q[1],q[6];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.5533478823294224) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(2.4027037617023828) q[6];
# rx(pi/2) q[6];
# rz(4.569468689553446) q[6];
# rx(pi/2) q[6];
# rz(8.175288542498508) q[6];
# cx q[1],q[6];
# rz(0.0637077381653044) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(6.0805777364808895) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(-pi/2) q[6];
# rx(pi/2) q[6];
# rz(3.538388280711141) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# rz(-pi/2) q[6];
# rx(pi/2) q[6];
# rz(3*pi/2) q[6];
# rx(pi/2) q[6];
# rz(10.175676295829861) q[6];
# cx q[6],q[0];
# rz(2.940637499910216) q[0];
# rx(pi/2) q[0];
# rz(4.35775267305643) q[0];
# rx(pi/2) q[0];
# rz(8.28590765000511) q[0];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(4.764046347766552) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# cx q[6],q[0];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.359572260079293) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(1.5199024671735017) q[0];
# rx(pi/2) q[0];
# rz(4.311686857555791) q[0];
# rx(pi/2) q[0];
# rz(7.983834937798657) q[0];
# rz(-0.01881807668976032) q[6];
# rx(pi/2) q[6];
# rz(3*pi/2) q[6];
# rx(pi/2) q[6];
# rz(7*pi/2) q[6];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(4.446883865456824) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# rz(2.832493455615502) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# rz(2.7250980048477924) q[7];
# rx(pi/2) q[7];
# rz(4.953368186066262) q[7];
# rx(pi/2) q[7];
# rz(9.319593265400142) q[7];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(3.144892624717154) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.687913307618526) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[3];
# rz(-0.37434256554384593) q[3];
# rx(pi/2) q[3];
# rz(4.557424655397022) q[3];
# rx(pi/2) q[3];
# rz(9.050435395225534) q[3];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.50755645896346) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[3];
# rz(2.0057018099940827) q[3];
# rx(pi/2) q[3];
# rz(5.0820281579160325) q[3];
# rx(pi/2) q[3];
# rz(6.449475399405039) q[3];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.288503261466566) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[3];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(6.0955898690976) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(0) q[3];
# rx(pi/2) q[3];
# rz(3.738709035835695) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# cx q[3],q[8];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(3.970354176556592) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# cx q[3],q[8];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(3.8892830855811233) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# cx q[3],q[8];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(3.701451629402706) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(3.221627567344739) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# cx q[3],q[4];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(4.460792407698586) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# cx q[3],q[4];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(4.324877744627358) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# cx q[3],q[4];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(3.3341835077584117) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(3*pi/2) q[3];
# rx(pi/2) q[3];
# rz(10.115546327668591) q[3];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.107243601805183) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(0.5173777410133873) q[4];
# rx(pi/2) q[4];
# rz(4.0594620623917566) q[4];
# rx(pi/2) q[4];
# rz(12.233507429291462) q[4];
# rz(2.8310859450970796) q[8];
# rx(pi/2) q[8];
# rz(4.842187741669376) q[8];
# rx(pi/2) q[8];
# rz(8.237386301541056) q[8];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(6.1258191269137745) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# cx q[8],q[5];
# rz(-0.37434256554384593) q[5];
# rx(pi/2) q[5];
# rz(4.557424655397022) q[5];
# rx(pi/2) q[5];
# rz(9.050435395225534) q[5];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.430626854197573) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[8],q[5];
# rz(2.0057018099940827) q[5];
# rx(pi/2) q[5];
# rz(5.0820281579160325) q[5];
# rx(pi/2) q[5];
# rz(6.449475399405039) q[5];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.428401209912844) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# cx q[8],q[5];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.8963734034137008) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(4.987070658582367) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(5.20112465363555) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(10.812040468611347) q[8];
# cx q[8],q[6];
# rz(1.7641129430976594) q[6];
# rx(pi/2) q[6];
# rz(4.704417558348383) q[6];
# rx(pi/2) q[6];
# rz(7.9361489316757226) q[6];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(6.079955822244337) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# cx q[8],q[6];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(3.4420990777138307) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# rz(0) q[6];
# rx(pi/2) q[6];
# rz(4.367681492996917) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# rz(-0.20644572162170371) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# rz(1.0307016539295235) q[8];
# rx(pi/2) q[8];
# rz(5.80736361660559) q[8];
# rx(pi/2) q[8];
# rz(7.260587871998722) q[8];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.656302915730066) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.6328879068974627) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[7];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.344627587657353) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[7];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.294903253918498) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[7];
# rz(2.4566156497946343) q[7];
# rx(pi/2) q[7];
# rz(4.976363278835009) q[7];
# rx(pi/2) q[7];
# rz(8.163132397752857) q[7];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(10.265802388930357) q[7];
# cx q[7],q[1];
# rz(2.72717263795251) q[1];
# rx(pi/2) q[1];
# rz(4.448160177139765) q[1];
# rx(pi/2) q[1];
# rz(8.25575802926259) q[1];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(5.129229234552857) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[1];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(3.500655301099191) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(3.502885613812481) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# cx q[1],q[0];
# rz(2.726849972105981) q[0];
# rx(pi/2) q[0];
# rz(4.448292507435033) q[0];
# rx(pi/2) q[0];
# rz(8.255697699415848) q[0];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.053735432296703) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# cx q[1],q[0];
# rz(2.977735761358921) q[0];
# rx(pi/2) q[0];
# rz(4.347643777259717) q[0];
# rx(pi/2) q[0];
# rz(9.858809931396344) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(5.649660759720293) q[0];
# rx(pi/2) q[0];
# rz(7*pi/2) q[0];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(4.978142838724643) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(3.370558688789343) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# cx q[1],q[8];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.591036980358211) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(-2.2816957022977746) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(7*pi/2) q[7];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(4.536114599451981) q[7];
# rx(pi/2) q[7];
# rz(7*pi/2) q[7];
# cx q[7],q[4];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.793708328975487) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# cx q[7],q[4];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.7903658216890093) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# cx q[7],q[4];
# rz(-0.7494962774212626) q[4];
# rx(pi/2) q[4];
# rz(4.429162572253543) q[4];
# rx(pi/2) q[4];
# rz(7.562270369109741) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(5.604357488435708) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# cx q[4],q[6];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.666648958965281) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(-0.37434256554384593) q[6];
# rx(pi/2) q[6];
# rz(4.557424655397022) q[6];
# rx(pi/2) q[6];
# rz(9.050435395225534) q[6];
# cx q[4],q[6];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.1331014218080835) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(2.0057018099940827) q[6];
# rx(pi/2) q[6];
# rz(5.0820281579160325) q[6];
# rx(pi/2) q[6];
# rz(6.449475399405039) q[6];
# cx q[4],q[6];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.699509707261439) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(4.833758799040371) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(3.2308654513716153) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(3.8372446688612847) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(4.4948917632677166) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(3.4703195812396297) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# cx q[1],q[8];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.493407136175721) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# cx q[1],q[8];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(3.4417019958704618) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(4.076315082889605) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(1.785743970627279) q[8];
# rx(pi/2) q[8];
# rz(5.107793343722087) q[8];
# rx(pi/2) q[8];
# rz(7.9378771849012315) q[8];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(9.537832436591945) q[8];
# cx q[8],q[4];
# rz(1.63292558681328) q[4];
# rx(pi/2) q[4];
# rz(4.711564560464496) q[4];
# rx(pi/2) q[4];
# rz(7.880510403913184) q[4];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(6.229097846241444) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# cx q[8],q[4];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(3.2169530922670146) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(4.051062332861079) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(-1.4878233340131557) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(7*pi/2) q[8];
# rz(-1.49402502705791) q[8];
# rx(pi/2) q[8];
# rz(4.315613112692352) q[8];
# rx(pi/2) q[8];
# rz(7.657499040062348) q[8];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(4.17184891547779) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.3743420718476855) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[9],q[2];
# rz(-0.37434256554384593) q[2];
# rx(pi/2) q[2];
# rz(4.557424655397022) q[2];
# rx(pi/2) q[2];
# rz(9.050435395225534) q[2];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.369467206029919) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[2];
# rz(2.0057018099940827) q[2];
# rx(pi/2) q[2];
# rz(5.0820281579160325) q[2];
# rx(pi/2) q[2];
# rz(6.449475399405039) q[2];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.277477817355381) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[2];
# rz(1.2642127845210362) q[2];
# rx(pi/2) q[2];
# rz(5.099169843641178) q[2];
# rx(pi/2) q[2];
# rz(10.876726015851483) q[2];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(5.2752142666997255) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# cx q[5],q[2];
# rz(-0.37434256554384593) q[2];
# rx(pi/2) q[2];
# rz(4.557424655397022) q[2];
# rx(pi/2) q[2];
# rz(9.050435395225534) q[2];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.606660860586771) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# cx q[5],q[2];
# rz(2.0057018099940827) q[2];
# rx(pi/2) q[2];
# rz(5.0820281579160325) q[2];
# rx(pi/2) q[2];
# rz(6.449475399405039) q[2];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.348339182035268) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# cx q[5],q[2];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(3.3540966606186378) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(8.134918443156547) q[2];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.48388389663191) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(5.304198798782747) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# cx q[7],q[5];
# rz(-0.37434256554384593) q[5];
# rx(pi/2) q[5];
# rz(4.557424655397022) q[5];
# rx(pi/2) q[5];
# rz(9.050435395225534) q[5];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.456245562084266) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# cx q[7],q[5];
# rz(2.0057018099940827) q[5];
# rx(pi/2) q[5];
# rz(5.0820281579160325) q[5];
# rx(pi/2) q[5];
# rz(6.449475399405039) q[5];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.256828466136618) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# cx q[7],q[5];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(5.048697263120214) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(3*pi/2) q[5];
# rx(pi/2) q[5];
# rz(10.071080646432158) q[5];
# cx q[5],q[1];
# rz(1.8977696095156649) q[1];
# rx(pi/2) q[1];
# rz(4.6896478900168095) q[1];
# rx(pi/2) q[1];
# rz(7.991628932672271) q[1];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(6.227809102719677) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# cx q[5],q[1];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.647628724898419) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(-1.5737764684450655) q[1];
# rx(pi/2) q[1];
# rz(5.116126301048217) q[1];
# rx(pi/2) q[1];
# rz(10.987988610409536) q[1];
# rz(-0.6294239529388519) q[5];
# rx(pi/2) q[5];
# rz(3*pi/2) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(3.5042130304118646) q[5];
# rx(pi/2) q[5];
# rz(7*pi/2) q[5];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.782518153108134) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(1.5641705473933811) q[7];
# rx(pi/2) q[7];
# rz(4.308692649356829) q[7];
# rx(pi/2) q[7];
# rz(7.870847486963131) q[7];
# cx q[6],q[7];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(4.888122754369196) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# rz(2.941185811524921) q[7];
# rx(pi/2) q[7];
# rz(4.357515648578277) q[7];
# rx(pi/2) q[7];
# rz(8.285959066961807) q[7];
# cx q[6],q[7];
# rz(0) q[6];
# rx(pi/2) q[6];
# rz(4.854348866895489) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# rz(0) q[6];
# rx(pi/2) q[6];
# rz(6.2670282198737235) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# cx q[6],q[4];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# rz(-pi/2) q[6];
# rx(pi/2) q[6];
# rz(4.635168586132433) q[6];
# rx(pi/2) q[6];
# rz(5*pi/2) q[6];
# cx q[6],q[4];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(4.545370892861609) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# cx q[6],q[4];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.1672081403388646) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(6.039953682228742) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(pi/2) q[6];
# rx(pi/2) q[6];
# rz(4.9761308662432615) q[6];
# rx(pi/2) q[6];
# rz(3*pi) q[6];
# rz(-pi) q[6];
# rx(pi/2) q[6];
# rz(pi) q[6];
# rx(pi/2) q[6];
# rz(2*pi) q[6];
# rz(2.976443976175166) q[6];
# rx(pi/2) q[6];
# rz(pi) q[6];
# rx(pi/2) q[6];
# rz(6.448333984594213) q[6];
# rz(-pi/2) q[6];
# rx(pi/2) q[6];
# rz(pi) q[6];
# rx(pi/2) q[6];
# rz(7*pi/2) q[6];
# rz(0.5585993153435629) q[6];
# rx(pi/2) q[6];
# rz(pi) q[6];
# rx(pi/2) q[6];
# rz(8.866178645425817) q[6];
# rz(-1.4271186647699219) q[6];
# rx(pi/2) q[6];
# rz(5.091026464977574) q[6];
# rx(pi/2) q[6];
# rz(11.368625398770519) q[6];
# rz(-2.820848301119298) q[7];
# rx(pi/2) q[7];
# rz(5.34814489781533) q[7];
# rx(pi/2) q[7];
# rz(9.934875932699903) q[7];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(11.17168847751806) q[7];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.2325781808630136) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(5.10385676519693) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[3],q[9];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(6.113645769239837) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(1.7550062518448568) q[9];
# rx(pi/2) q[9];
# rz(4.70514993091784) q[9];
# rx(pi/2) q[9];
# rz(7.932315170315134) q[9];
# cx q[3],q[9];
# rz(-1.0063432045228864) q[3];
# rx(pi/2) q[3];
# rz(3*pi/2) q[3];
# rx(pi/2) q[3];
# rz(7*pi/2) q[3];
# rz(0.9454086105360622) q[3];
# rx(pi/2) q[3];
# rz(3.6474769193970733) q[3];
# rx(pi/2) q[3];
# rz(11.685652090526208) q[3];
# cx q[0],q[3];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.8763875724556236) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[3];
# rx(pi/2) q[3];
# rz(4.557424655397022) q[3];
# rx(pi/2) q[3];
# rz(9.050435395225534) q[3];
# cx q[0],q[3];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.830417458605396) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[3];
# rx(pi/2) q[3];
# rz(5.0820281579160325) q[3];
# rx(pi/2) q[3];
# rz(6.449475399405039) q[3];
# cx q[0],q[3];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(5.6054718961866) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(3.2914314334601404) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-1.3443941017987122) q[3];
# rx(pi/2) q[3];
# rz(4.317897190055146) q[3];
# rx(pi/2) q[3];
# rz(7.765678773868014) q[3];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(3*pi/2) q[3];
# rx(pi/2) q[3];
# rz(10.511637821147293) q[3];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.404077718540139) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.5702462296378275) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[2],q[9];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(6.024590314402802) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(2.193573894212892) q[9];
# rx(pi/2) q[9];
# rz(4.630943405319426) q[9];
# rx(pi/2) q[9];
# rz(8.10582894977676) q[9];
# cx q[2],q[9];
# rz(-2.1800673193740225) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(6.2156341417068335) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# cx q[2],q[0];
# rz(-0.37434256554384593) q[0];
# rx(pi/2) q[0];
# rz(4.557424655397022) q[0];
# rx(pi/2) q[0];
# rz(9.050435395225534) q[0];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.500855043654003) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# cx q[2],q[0];
# rz(2.0057018099940827) q[0];
# rx(pi/2) q[0];
# rz(5.0820281579160325) q[0];
# rx(pi/2) q[0];
# rz(6.449475399405039) q[0];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.230690781067832) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# cx q[2],q[0];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.000880974505248) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(6.109152370347488) q[0];
# rx(pi/2) q[0];
# rz(7*pi/2) q[0];
# cx q[0],q[8];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(5.079875805268578) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(5.742211724433542) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(5.017111703037012) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# cx q[7],q[2];
# rz(2.618460425386842) q[2];
# rx(pi/2) q[2];
# rz(4.491639576238525) q[2];
# rx(pi/2) q[2];
# rz(8.233078015680073) q[2];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(5.496667144083009) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[2];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(3.3334131888466194) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(5.593884899303172) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# rz(-0.5309708892274507) q[7];
# rx(pi/2) q[7];
# rz(3*pi/2) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(4.648065740627142) q[7];
# rx(pi/2) q[7];
# rz(7*pi/2) q[7];
# rz(2.6818216117414826) q[8];
# rx(pi/2) q[8];
# rz(4.466579597301685) q[8];
# rx(pi/2) q[8];
# rz(8.246864334459046) q[8];
# cx q[0],q[8];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(4.404005370737817) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(0.5335457500271916) q[0];
# rx(pi/2) q[0];
# rz(4.0243059870455085) q[0];
# rx(pi/2) q[0];
# rz(12.207492901357721) q[0];
# cx q[7],q[0];
# rz(-0.37434256554384593) q[0];
# rx(pi/2) q[0];
# rz(4.557424655397022) q[0];
# rx(pi/2) q[0];
# rz(9.050435395225534) q[0];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.43173327942513) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# cx q[7],q[0];
# rz(2.0057018099940827) q[0];
# rx(pi/2) q[0];
# rz(5.0820281579160325) q[0];
# rx(pi/2) q[0];
# rz(6.449475399405039) q[0];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.1759705367520645) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# cx q[7],q[0];
# rz(-0.2046177026557583) q[0];
# rx(pi/2) q[0];
# rz(4.62579842715588) q[0];
# rx(pi/2) q[0];
# rz(10.600722091968436) q[0];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(4.007972142031268) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(4.962983429443502) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-2.648595095705928) q[7];
# rx(pi/2) q[7];
# rz(5.3038710375023275) q[7];
# rx(pi/2) q[7];
# rz(6.574241409344914) q[7];
# rz(0.08976064071661893) q[8];
# rx(pi/2) q[8];
# rz(4.505566276237422) q[8];
# rx(pi/2) q[8];
# rz(9.011708554277584) q[8];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(3.2309830813586045) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(5.3340708246972985) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(3.9708898819533682) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[3],q[9];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(5.989701327049659) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(1.91621084253328) q[9];
# rx(pi/2) q[9];
# rz(4.687023400612759) q[9];
# rx(pi/2) q[9];
# rz(7.999141190916523) q[9];
# cx q[3],q[9];
# rz(-0.33388057579174335) q[3];
# rx(pi/2) q[3];
# rz(3*pi/2) q[3];
# rx(pi/2) q[3];
# rz(7*pi/2) q[3];
# rz(0) q[3];
# rx(pi/2) q[3];
# rz(5.817233422350231) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# cx q[3],q[1];
# rz(2.9144140760178603) q[1];
# rx(pi/2) q[1];
# rz(4.369073466065908) q[1];
# rx(pi/2) q[1];
# rz(8.283288687063283) q[1];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(4.835810517008755) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# cx q[3],q[1];
# rz(-2.93274228023755) q[1];
# rx(pi/2) q[1];
# rz(5.164219996954618) q[1];
# rx(pi/2) q[1];
# rz(9.876693575197566) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(5.689057827023234) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(4.610351305323279) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(-3.1185929356841737) q[3];
# rx(pi/2) q[3];
# rz(pi) q[3];
# rx(pi/2) q[3];
# rz(12.543370896453553) q[3];
# rz(-0.14925318381089703) q[3];
# rx(pi/2) q[3];
# rz(pi) q[3];
# rx(pi/2) q[3];
# rz(9.574031144580278) q[3];
# rz(2.696161319425592) q[3];
# rx(pi/2) q[3];
# rz(pi) q[3];
# rx(pi/2) q[3];
# rz(6.728616641343788) q[3];
# rz(0) q[3];
# rx(pi/2) q[3];
# rz(5.517767279857957) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# cx q[3],q[6];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(6.251806235452937) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(1.6178369786942524) q[6];
# rx(pi/2) q[6];
# rz(4.711916341092469) q[6];
# rx(pi/2) q[6];
# rz(7.874072182397486) q[6];
# cx q[3],q[6];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(3.8974725980423504) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(-0.4039362936002111) q[3];
# rx(pi/2) q[3];
# rz(4.742095225390847) q[3];
# rx(pi/2) q[3];
# rz(9.412082846173705) q[3];
# rz(-0.8805798664668676) q[6];
# rx(pi/2) q[6];
# rz(5.777252516348398) q[6];
# rx(pi/2) q[6];
# rz(11.62108329221346) q[6];
# rz(0) q[6];
# rx(pi/2) q[6];
# rz(5.180504319354894) q[6];
# rx(pi/2) q[6];
# rz(7*pi/2) q[6];
# cx q[8],q[1];
# rz(-0.37434256554384593) q[1];
# rx(pi/2) q[1];
# rz(4.557424655397022) q[1];
# rx(pi/2) q[1];
# rz(9.050435395225534) q[1];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(3.200443541011708) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[8],q[1];
# rz(2.0057018099940827) q[1];
# rx(pi/2) q[1];
# rz(5.0820281579160325) q[1];
# rx(pi/2) q[1];
# rz(6.449475399405039) q[1];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(3.165668409604665) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# cx q[8],q[1];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.141587649841182) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(4.564336193646577) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(3.2402896265150485) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(3.274334378200632) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[8],q[7];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.4862974454788365) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[8],q[7];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.3809028631614755) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# cx q[8],q[7];
# rz(1.5192773445011412) q[7];
# rx(pi/2) q[7];
# rz(5.115657249017521) q[7];
# rx(pi/2) q[7];
# rz(7.83374907358492) q[7];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(5.286899336277256) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(4.057910331091392) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(11.225536538055458) q[8];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.000569724417511) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(-1.6185432866057816) q[9];
# rx(pi/2) q[9];
# rz(5.878950098551794) q[9];
# rx(pi/2) q[9];
# rz(7.802056308747625) q[9];
# cx q[5],q[9];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.419902371198923) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(-0.37434256554384593) q[9];
# rx(pi/2) q[9];
# rz(4.557424655397022) q[9];
# rx(pi/2) q[9];
# rz(9.050435395225534) q[9];
# cx q[5],q[9];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.389042408405572) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(2.0057018099940827) q[9];
# rx(pi/2) q[9];
# rz(5.0820281579160325) q[9];
# rx(pi/2) q[9];
# rz(6.449475399405039) q[9];
# cx q[5],q[9];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(3.2262226243945618) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(-1.5810401670899907) q[5];
# rx(pi/2) q[5];
# rz(4.308764101825841) q[5];
# rx(pi/2) q[5];
# rz(7.880058677469842) q[5];
# cx q[2],q[5];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.83386828820269) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(2.948060292941859) q[5];
# rx(pi/2) q[5];
# rz(4.354543027717103) q[5];
# rx(pi/2) q[5];
# rz(8.286592042057608) q[5];
# cx q[2],q[5];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(4.610946157889149) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(4.572076069422335) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(0.3154703031048838) q[5];
# rx(pi/2) q[5];
# rz(4.084267132637728) q[5];
# rx(pi/2) q[5];
# rz(8.91779545162492) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(4.786425426385541) q[5];
# rx(pi/2) q[5];
# rz(7*pi/2) q[5];
# cx q[1],q[5];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.61774919045013) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(-0.37434256554384593) q[5];
# rx(pi/2) q[5];
# rz(4.557424655397022) q[5];
# rx(pi/2) q[5];
# rz(9.050435395225534) q[5];
# cx q[1],q[5];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.138133218782892) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(2.0057018099940827) q[5];
# rx(pi/2) q[5];
# rz(5.0820281579160325) q[5];
# rx(pi/2) q[5];
# rz(6.449475399405039) q[5];
# cx q[1],q[5];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.909364023692059) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(-1.5847923904125825) q[1];
# rx(pi/2) q[1];
# rz(5.115907353050208) q[1];
# rx(pi/2) q[1];
# rz(10.959942504386438) q[1];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.147241177219773) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(3*pi/2) q[5];
# rx(pi/2) q[5];
# rz(11.94235990073318) q[5];
# cx q[7],q[1];
# rz(2.578755085496364) q[1];
# rx(pi/2) q[1];
# rz(4.50688978159028) q[1];
# rx(pi/2) q[1];
# rz(8.223661715243288) q[1];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(5.598800439468728) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[1];
# rz(-2.556208245702271) q[1];
# rx(pi/2) q[1];
# rz(5.624989957421205) q[1];
# rx(pi/2) q[1];
# rz(10.122228215718257) q[1];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(3.3731225959948907) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(4.278706832072422) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(5.518631383500484) q[7];
# rx(pi/2) q[7];
# rz(7*pi/2) q[7];
# rz(1.1931346810131531) q[9];
# rx(pi/2) q[9];
# rz(5.090402881058404) q[9];
# rx(pi/2) q[9];
# rz(10.85019365237811) q[9];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(3*pi/2) q[9];
# rx(pi/2) q[9];
# rz(7.69161863115645) q[9];
# cx q[9],q[4];
# rz(2.2712616880130767) q[4];
# rx(pi/2) q[4];
# rz(4.609904136530321) q[4];
# rx(pi/2) q[4];
# rz(8.132959676611321) q[4];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(6.074939151248154) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[4];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.5830121629963365) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(6.017430238115012) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[0],q[4];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.459566445586534) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# cx q[0],q[4];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.2725624673727407) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# cx q[0],q[4];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.00906465770952) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(4.286463417931896) q[0];
# rx(pi/2) q[0];
# rz(7*pi/2) q[0];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.127693833316167) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(3.7098230835370143) q[4];
# rx(pi/2) q[4];
# rz(7*pi/2) q[4];
# cx q[5],q[4];
# rz(2.135060118229857) q[4];
# rx(pi/2) q[4];
# rz(4.645300351753626) q[4];
# rx(pi/2) q[4];
# rz(8.084491064457541) q[4];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(6.063028399444891) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# cx q[5],q[4];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.050445916169793) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(5.073209106452274) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[1],q[4];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.568435567802103) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# cx q[1],q[4];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.155361382775968) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# cx q[1],q[4];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.003700143470763) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(5.826622718081122) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.290798026418814) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(6.220441059589196) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(1.5679307151219612) q[5];
# rx(pi/2) q[5];
# rz(3*pi/2) q[5];
# rx(pi/2) q[5];
# rz(7*pi/2) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(4.078406186119429) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(2.2384286877242046) q[9];
# rx(pi/2) q[9];
# rz(3*pi/2) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.6619569953254993) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[2];
# rz(-0.37434256554384593) q[2];
# rx(pi/2) q[2];
# rz(4.557424655397022) q[2];
# rx(pi/2) q[2];
# rz(9.050435395225534) q[2];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.533407603900729) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[2];
# rz(2.0057018099940827) q[2];
# rx(pi/2) q[2];
# rz(5.0820281579160325) q[2];
# rx(pi/2) q[2];
# rz(6.449475399405039) q[2];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.1469038318149245) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[2];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(5.141560306207425) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(0.4053502880377069) q[2];
# rx(pi/2) q[2];
# rz(4.7988553624899914) q[2];
# rx(pi/2) q[2];
# rz(6.320226097547802) q[2];
# cx q[0],q[2];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.285626290124011) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[2];
# rx(pi/2) q[2];
# rz(4.557424655397022) q[2];
# rx(pi/2) q[2];
# rz(9.050435395225534) q[2];
# cx q[0],q[2];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.005050688303529) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[2];
# rx(pi/2) q[2];
# rz(5.0820281579160325) q[2];
# rx(pi/2) q[2];
# rz(6.449475399405039) q[2];
# cx q[0],q[2];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(3.9372151585174975) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(-0.5040930252340905) q[0];
# rx(pi/2) q[0];
# rz(5.333267805783063) q[0];
# rx(pi/2) q[0];
# rz(9.114249509331557) q[0];
# rz(0.02991071969838277) q[2];
# rx(pi/2) q[2];
# rz(4.725164774371491) q[2];
# rx(pi/2) q[2];
# rz(7.450425002307513) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(4.151376760388491) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# cx q[7],q[0];
# rz(-0.37434256554384593) q[0];
# rx(pi/2) q[0];
# rz(4.557424655397022) q[0];
# rx(pi/2) q[0];
# rz(9.050435395225534) q[0];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.8891889535498385) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# cx q[7],q[0];
# rz(2.0057018099940827) q[0];
# rx(pi/2) q[0];
# rz(5.0820281579160325) q[0];
# rx(pi/2) q[0];
# rz(6.449475399405039) q[0];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.2134252924835955) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[0];
# rz(0.48844120573476335) q[0];
# rx(pi/2) q[0];
# rz(4.910238313962105) q[0];
# rx(pi/2) q[0];
# rz(7.499688304959275) q[0];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(3.459416836279679) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(5.907182027900365) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(4.4808835828184295) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# cx q[7],q[1];
# rz(-0.37434256554384593) q[1];
# rx(pi/2) q[1];
# rz(4.557424655397022) q[1];
# rx(pi/2) q[1];
# rz(9.050435395225534) q[1];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.374858077398327) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# cx q[7],q[1];
# rz(2.0057018099940827) q[1];
# rx(pi/2) q[1];
# rz(5.0820281579160325) q[1];
# rx(pi/2) q[1];
# rz(6.449475399405039) q[1];
# rz(pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.144957794337897) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# cx q[7],q[1];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.943996964788996) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(10.333089725362754) q[1];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(4.3166145896508805) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(5.297901728975615) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.4830645916573335) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.422200673277873) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[8],q[9];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(6.148929540641339) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# rz(1.8922387417129407) q[9];
# rx(pi/2) q[9];
# rz(4.690407484752097) q[9];
# rx(pi/2) q[9];
# rz(7.989368113194468) q[9];
# cx q[8],q[9];
# rz(0.5664451677337992) q[8];
# rx(pi/2) q[8];
# rz(3*pi/2) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(6.163921937704676) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[5],q[8];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.537025105758186) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# cx q[5],q[8];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.5352839399742093) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# cx q[5],q[8];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.096857926145289) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(5.745480572801437) q[5];
# rx(pi/2) q[5];
# rz(7*pi/2) q[5];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(5.26722228426111) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(5.663470793327193) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[0],q[8];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.029050266757036) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# cx q[0],q[8];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.845821575324827) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# cx q[0],q[8];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.508479449030271) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(5.714687144682785) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(5.0672169658741595) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(4.036516369633603) q[8];
# rx(pi/2) q[8];
# rz(7*pi/2) q[8];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.932239697777019) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(1.6055716236526472) q[9];
# rx(pi/2) q[9];
# rz(4.310059678777688) q[9];
# rx(pi/2) q[9];
# rz(7.765366934041314) q[9];
# cx q[2],q[9];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(6.220679018755402) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(1.7938415379818675) q[9];
# rx(pi/2) q[9];
# rz(4.701782463088625) q[9];
# rx(pi/2) q[9];
# rz(7.948623632925198) q[9];
# cx q[2],q[9];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(5.282750077393748) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(-1.6279052915661605) q[2];
# rx(pi/2) q[2];
# rz(4.312480783546696) q[2];
# rx(pi/2) q[2];
# rz(7.999783109681948) q[2];
# cx q[5],q[2];
# rz(2.9437143266463455) q[2];
# rx(pi/2) q[2];
# rz(4.3564224773339655) q[2];
# rx(pi/2) q[2];
# rz(8.286194396046541) q[2];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.834077331727378) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# cx q[5],q[2];
# rz(0.25547582499053245) q[2];
# rx(pi/2) q[2];
# rz(4.178231757298298) q[2];
# rx(pi/2) q[2];
# rz(8.950774313245647) q[2];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(12.180734757074527) q[2];
# cx q[2],q[7];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(6.004113603415116) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(4.546766580373845) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(4.232321699951368) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# cx q[1],q[5];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.526133160855306) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(2.291905499884333) q[5];
# rx(pi/2) q[5];
# rz(4.603946014750873) q[5];
# rx(pi/2) q[5];
# rz(8.139919124341178) q[5];
# cx q[1],q[5];
# rz(-0.3908127582451666) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(4.010448967726439) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(4.010532204932596) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(3.976269842908498) q[5];
# rx(pi/2) q[5];
# rz(7*pi/2) q[5];
# rz(2.242135852142887) q[7];
# rx(pi/2) q[7];
# rz(4.618050789068317) q[7];
# rx(pi/2) q[7];
# rz(8.122957886226276) q[7];
# cx q[2],q[7];
# rz(0.4990052220798358) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(12.540799218196883) q[2];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.9862231038394604) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-2.072403578129932) q[7];
# rx(pi/2) q[7];
# rz(3.60619138147129) q[7];
# rx(pi/2) q[7];
# rz(11.54579726828808) q[7];
# cx q[5],q[7];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.425603172104551) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# cx q[5],q[7];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(3.169222233236953) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# cx q[5],q[7];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(3.920184980532981) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(1.9728026459341255) q[5];
# rx(pi/2) q[5];
# rz(4.673866783105142) q[5];
# rx(pi/2) q[5];
# rz(6.373522665570656) q[5];
# rz(-1.1951732680693123) q[7];
# rx(pi/2) q[7];
# rz(4.33409841882067) q[7];
# rx(pi/2) q[7];
# rz(10.850946306860411) q[7];
# rz(-1.8652196496447968) q[7];
# rx(pi/2) q[7];
# rz(4.431989269020819) q[7];
# rx(pi/2) q[7];
# rz(8.68503378121828) q[7];
# rz(1.6530679754806492) q[9];
# rx(pi/2) q[9];
# rz(3.5465658648300935) q[9];
# rx(pi/2) q[9];
# rz(7.778338231605011) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(4.718053212021804) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[4],q[9];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.355120175807572) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(-0.37434256554384593) q[9];
# rx(pi/2) q[9];
# rz(4.557424655397022) q[9];
# rx(pi/2) q[9];
# rz(9.050435395225534) q[9];
# cx q[4],q[9];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.289916878827777) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(2.0057018099940827) q[9];
# rx(pi/2) q[9];
# rz(5.0820281579160325) q[9];
# rx(pi/2) q[9];
# rz(6.449475399405039) q[9];
# cx q[4],q[9];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.211275896007173) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(4.690554774487182) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[0],q[4];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.527797994380961) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# cx q[0],q[4];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.404544401291851) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# cx q[0],q[4];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.4715447636291845) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(4.4224066156593915) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# cx q[2],q[0];
# rz(2.9035805054673522) q[0];
# rx(pi/2) q[0];
# rz(4.3737401646726495) q[0];
# rx(pi/2) q[0];
# rz(8.282115695057644) q[0];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.820476711487989) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# cx q[2],q[0];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.281498848517103) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(5.227264236974146) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# cx q[0],q[5];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(6.211384684391243) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(0.06923355766104189) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(4.621990849549457) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(3.447072200790733) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(6.003434087248229) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[4],q[3];
# rz(-0.37434256554384593) q[3];
# rx(pi/2) q[3];
# rz(4.557424655397022) q[3];
# rx(pi/2) q[3];
# rz(9.050435395225534) q[3];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.621447086222405) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[4],q[3];
# rz(2.0057018099940827) q[3];
# rx(pi/2) q[3];
# rz(5.0820281579160325) q[3];
# rx(pi/2) q[3];
# rz(6.449475399405039) q[3];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.549035022289447) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# cx q[4],q[3];
# rz(-1.7806608617447068) q[3];
# rx(pi/2) q[3];
# rz(4.3165948027666925) q[3];
# rx(pi/2) q[3];
# rz(7.935918348108917) q[3];
# rz(2.6438561424832017) q[3];
# rx(pi/2) q[3];
# rz(4.108029265844437) q[3];
# rx(pi/2) q[3];
# rz(9.724252295297529) q[3];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(4.655593205158083) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(5.835501417725274) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(1.8850087239977622) q[5];
# rx(pi/2) q[5];
# rz(4.6913812364753875) q[5];
# rx(pi/2) q[5];
# rz(7.986407519512044) q[5];
# cx q[0],q[5];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(4.100475850393273) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(3.252374028475076) q[0];
# rx(pi/2) q[0];
# rz(7*pi/2) q[0];
# rz(-0.03209393315621112) q[5];
# rx(pi/2) q[5];
# rz(4.787358417978178) q[5];
# rx(pi/2) q[5];
# rz(9.019826546647273) q[5];
# rz(0.5963313321764905) q[5];
# rx(pi/2) q[5];
# rz(5.508436082069177) q[5];
# rx(pi/2) q[5];
# rz(6.734795658806156) q[5];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.75103174611844) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(5.083014800921515) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[8];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.6866439460006553) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[8];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.255480346908085) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[8];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.573802297071342) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(6.168324811825866) q[8];
# rx(pi/2) q[8];
# ...
# rx(pi/2) q[6];
# rz(5.016529610513198) q[6];
# rx(pi/2) q[6];
# rz(10.250009064513604) q[6];
# rz(2.125599970932231) q[7];
# rx(pi/2) q[7];
# rz(4.647498145657192) q[7];
# rx(pi/2) q[7];
# rz(8.08097424405129) q[7];
# cx q[2],q[7];
# rz(0.34486723956989085) q[2];
# rx(pi/2) q[2];
# rz(3*pi/2) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# rz(-1.5998876947277383) q[2];
# rx(pi/2) q[2];
# rz(4.309633253712525) q[2];
# rx(pi/2) q[2];
# rz(7.928087807072332) q[2];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.4629668931654654) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# rz(1.5053634154777473) q[7];
# rx(pi/2) q[7];
# rz(5.878521218799291) q[7];
# rx(pi/2) q[7];
# rz(7.782818302592984) q[7];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.659222813739615) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(4.284107912916916) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[4];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.549953477387152) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[4];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.991584240069038) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[4];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.6279016499608865) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(5.479237113259306) q[4];
# rx(pi/2) q[4];
# rz(7*pi/2) q[4];
# cx q[4],q[1];
# rz(2.748038534384186) q[1];
# rx(pi/2) q[1];
# rz(4.439566589034814) q[1];
# rx(pi/2) q[1];
# rz(8.259568329899619) q[1];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(5.279859423619661) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# cx q[4],q[1];
# rz(0.8676247327377542) q[1];
# rx(pi/2) q[1];
# rz(3.6521334712194236) q[1];
# rx(pi/2) q[1];
# rz(11.632401015123637) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(5.57076163586653) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# cx q[1],q[2];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.379366572558592) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(2.8449644691310336) q[2];
# rx(pi/2) q[2];
# rz(4.398845483254428) q[2];
# rx(pi/2) q[2];
# rz(8.27485768636899) q[2];
# cx q[1],q[2];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(4.205208087927728) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(-pi/2) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(11.553925134298101) q[1];
# cx q[1],q[3];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(5.807776971799413) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(0.3613853562266689) q[2];
# rx(pi/2) q[2];
# rz(4.021037025263339) q[2];
# rx(pi/2) q[2];
# rz(8.88963654643188) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(4.827182183866206) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(2.222731083096482) q[3];
# rx(pi/2) q[3];
# rz(4.623307127352994) q[3];
# rx(pi/2) q[3];
# rz(8.116179562119799) q[3];
# cx q[1],q[3];
# rz(0.3387568485629391) q[1];
# rx(pi/2) q[1];
# rz(3*pi/2) q[1];
# rx(pi/2) q[1];
# rz(7*pi/2) q[1];
# rz(-pi) q[1];
# rx(pi/2) q[1];
# rz(3.7556394620744378) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(pi/2) q[3];
# rx(pi/2) q[3];
# rz(3.2226221585689676) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(-0.49674550975852316) q[3];
# rx(pi/2) q[3];
# rz(5.314096979870746) q[3];
# rx(pi/2) q[3];
# rz(9.127050978974141) q[3];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(3.9250714771933044) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(3*pi/2) q[4];
# rx(pi/2) q[4];
# rz(12.100616744080252) q[4];
# cx q[4],q[0];
# rz(2.9117410298345643) q[0];
# rx(pi/2) q[0];
# rz(4.3702255358122315) q[0];
# rx(pi/2) q[0];
# rz(8.28300419468993) q[0];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.936060108763056) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# cx q[4],q[0];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.7764617897358863) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(3.8795513070344985) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(0.009339109701859805) q[4];
# rx(pi/2) q[4];
# rz(3*pi/2) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(0) q[4];
# rx(pi/2) q[4];
# rz(3.294952603781533) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.906321946583498) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# rz(1.5058983112430662) q[9];
# rx(pi/2) q[9];
# rz(4.313608102237198) q[9];
# rx(pi/2) q[9];
# rz(8.019815355626891) q[9];
# cx q[8],q[9];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.783220919991392) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# rz(2.9373534818091898) q[9];
# rx(pi/2) q[9];
# rz(4.359172050335597) q[9];
# rx(pi/2) q[9];
# rz(8.285596822784203) q[9];
# cx q[8],q[9];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(4.812410663156917) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(1.711403250927602) q[8];
# rx(pi/2) q[8];
# rz(4.332648670450265) q[8];
# rx(pi/2) q[8];
# rz(7.489226025493827) q[8];
# cx q[5],q[8];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(5.927743531369192) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(2.1169290944283965) q[8];
# rx(pi/2) q[8];
# rz(4.649482056114097) q[8];
# rx(pi/2) q[8];
# rz(8.077735194268946) q[8];
# cx q[5],q[8];
# rz(0) q[5];
# rx(pi/2) q[5];
# rz(4.522263846023114) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(pi) q[5];
# rx(pi/2) q[5];
# rz(4.170774818330656) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# cx q[5],q[6];
# rz(pi/2) q[5];
# rx(pi/2) q[5];
# rz(6.147199732787451) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(1.6964926386364585) q[6];
# rx(pi/2) q[6];
# rz(4.709016076334671) q[6];
# rx(pi/2) q[6];
# rz(7.90756569133382) q[6];
# cx q[5],q[6];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(5.325893974041554) q[5];
# rx(pi/2) q[5];
# rz(2*pi) q[5];
# rz(-pi) q[5];
# rx(pi/2) q[5];
# rz(3.5876395534824437) q[5];
# rx(pi/2) q[5];
# rz(5*pi/2) q[5];
# rz(-2.6726038446013116) q[6];
# rx(pi/2) q[6];
# rz(5.525949118333143) q[6];
# rx(pi/2) q[6];
# rz(6.892041829941654) q[6];
# rz(1.5380284371772506) q[6];
# rx(pi/2) q[6];
# rz(4.309900342641052) q[6];
# rx(pi/2) q[6];
# rz(7.937470647251345) q[6];
# cx q[1],q[6];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(4.777795340983939) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(2.9378703367179106) q[6];
# rx(pi/2) q[6];
# rz(4.358948689543297) q[6];
# rx(pi/2) q[6];
# rz(8.285646068805928) q[6];
# cx q[1],q[6];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(4.7672285432646895) q[1];
# rx(pi/2) q[1];
# rz(3*pi) q[1];
# rz(0) q[1];
# rx(pi/2) q[1];
# rz(4.706767450691705) q[1];
# rx(pi/2) q[1];
# rz(5*pi/2) q[1];
# rz(-2.861085028825645) q[6];
# rx(pi/2) q[6];
# rz(5.287367291414029) q[6];
# rx(pi/2) q[6];
# rz(9.911965994196688) q[6];
# rz(2.734876252368144) q[6];
# rx(pi/2) q[6];
# rz(4.5948771709225085) q[6];
# rx(pi/2) q[6];
# rz(9.475234883570476) q[6];
# rz(0.7212730249464552) q[8];
# rx(pi/2) q[8];
# rz(3.7158316001581175) q[8];
# rx(pi/2) q[8];
# rz(8.616278371308287) q[8];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(5.81695674608) q[8];
# rx(pi/2) q[8];
# rz(2*pi) q[8];
# cx q[8],q[4];
# rz(-0.37434256554384593) q[4];
# rx(pi/2) q[4];
# rz(4.557424655397022) q[4];
# rx(pi/2) q[4];
# rz(9.050435395225534) q[4];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.036653775550235) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# cx q[8],q[4];
# rz(2.0057018099940827) q[4];
# rx(pi/2) q[4];
# rz(5.0820281579160325) q[4];
# rx(pi/2) q[4];
# rz(6.449475399405039) q[4];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(3.863676540814321) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# cx q[8],q[4];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(3.717375575853821) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(-1.331920045565374) q[4];
# rx(pi/2) q[4];
# rz(5.041064714313871) q[4];
# rx(pi/2) q[4];
# rz(11.641911693106744) q[4];
# rz(pi/2) q[8];
# rx(pi/2) q[8];
# rz(5.982711224701501) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(0) q[8];
# rx(pi/2) q[8];
# rz(3.3368354332388073) q[8];
# rx(pi/2) q[8];
# rz(7*pi/2) q[8];
# rz(-2.9684154128249993) q[9];
# rx(pi/2) q[9];
# rz(5.095769069098297) q[9];
# rx(pi/2) q[9];
# rz(9.862215757377218) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.2337553366777576) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[9],q[7];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(4.180454343992931) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[7];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.811342736519233) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# cx q[9],q[7];
# rz(1.466402108411911) q[7];
# rx(pi/2) q[7];
# rz(5.1141681942811585) q[7];
# rx(pi/2) q[7];
# rz(10.954624204662922) q[7];
# rz(0) q[7];
# rx(pi/2) q[7];
# rz(5.061427604787662) q[7];
# rx(pi/2) q[7];
# rz(7*pi/2) q[7];
# cx q[2],q[7];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.160951789270053) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# cx q[2],q[7];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(3.989413239132583) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# cx q[2],q[7];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.496925900149933) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(3.7891038571237496) q[2];
# rx(pi/2) q[2];
# rz(7*pi/2) q[2];
# cx q[2],q[3];
# rz(-pi/2) q[2];
# rx(pi/2) q[2];
# rz(4.269348227808132) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(-0.37434256554384593) q[3];
# rx(pi/2) q[3];
# rz(4.557424655397022) q[3];
# rx(pi/2) q[3];
# rz(9.050435395225534) q[3];
# cx q[2],q[3];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(3.9070784966085164) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(2.0057018099940827) q[3];
# rx(pi/2) q[3];
# rz(5.0820281579160325) q[3];
# rx(pi/2) q[3];
# rz(6.449475399405039) q[3];
# cx q[2],q[3];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(4.213074600345211) q[2];
# rx(pi/2) q[2];
# rz(3*pi) q[2];
# rz(-pi) q[2];
# rx(pi/2) q[2];
# rz(3.718228046961826) q[2];
# rx(pi/2) q[2];
# rz(5*pi/2) q[2];
# rz(1.1500028377858378) q[3];
# rx(pi/2) q[3];
# rz(5.084201285794419) q[3];
# rx(pi/2) q[3];
# rz(7.6928042805890495) q[3];
# rz(0) q[3];
# rx(pi/2) q[3];
# rz(3.285012843336967) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# cx q[3],q[6];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(4.505170924551226) q[3];
# rx(pi/2) q[3];
# rz(5*pi/2) q[3];
# rz(-0.37434256554384593) q[6];
# rx(pi/2) q[6];
# rz(4.557424655397022) q[6];
# rx(pi/2) q[6];
# rz(9.050435395225534) q[6];
# cx q[3],q[6];
# rz(-pi/2) q[3];
# rx(pi/2) q[3];
# rz(3.1724500937639792) q[3];
# rx(pi/2) q[3];
# rz(2*pi) q[3];
# rz(2.0057018099940827) q[6];
# rx(pi/2) q[6];
# rz(5.0820281579160325) q[6];
# rx(pi/2) q[6];
# rz(6.449475399405039) q[6];
# cx q[3],q[6];
# rz(-pi) q[3];
# rx(pi/2) q[3];
# rz(4.912133271663935) q[3];
# rx(pi/2) q[3];
# rz(3*pi) q[3];
# rz(-1.614978819839516) q[6];
# rx(pi/2) q[6];
# rz(4.308993886067078) q[6];
# rx(pi/2) q[6];
# rz(11.012927376086937) q[6];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.4047159275953223) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-pi) q[7];
# rx(pi/2) q[7];
# rz(5.354274795353855) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# cx q[7],q[8];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.2444084555294435) q[7];
# rx(pi/2) q[7];
# rz(5*pi/2) q[7];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# cx q[7],q[8];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(3.210587204261948) q[7];
# rx(pi/2) q[7];
# rz(2*pi) q[7];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# cx q[7],q[8];
# rz(-pi/2) q[7];
# rx(pi/2) q[7];
# rz(5.536371121023644) q[7];
# rx(pi/2) q[7];
# rz(3*pi) q[7];
# rz(-2.7084575851717285) q[7];
# rx(pi/2) q[7];
# rz(5.072021290816518) q[7];
# rx(pi/2) q[7];
# rz(6.444510888149805) q[7];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(4.288196123236208) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(-pi) q[8];
# rx(pi/2) q[8];
# rz(3.7383145224318826) q[8];
# rx(pi/2) q[8];
# rz(5*pi/2) q[8];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(3.190999710173247) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# rz(0) q[9];
# rx(pi/2) q[9];
# rz(3.1733807143867527) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[0],q[9];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.4946872198895775) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[9];
# rx(pi/2) q[9];
# rz(4.557424655397022) q[9];
# rx(pi/2) q[9];
# rz(9.050435395225534) q[9];
# cx q[0],q[9];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.364098984885983) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[9];
# rx(pi/2) q[9];
# rz(5.0820281579160325) q[9];
# rx(pi/2) q[9];
# rz(6.449475399405039) q[9];
# cx q[0],q[9];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(5.6801135139897125) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(0) q[0];
# rx(pi/2) q[0];
# rz(4.880955114241477) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# cx q[0],q[5];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.469229563518274) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[5];
# rx(pi/2) q[5];
# rz(4.557424655397022) q[5];
# rx(pi/2) q[5];
# rz(9.050435395225534) q[5];
# cx q[0],q[5];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.173851807737789) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[5];
# rx(pi/2) q[5];
# rz(5.0820281579160325) q[5];
# rx(pi/2) q[5];
# rz(6.449475399405039) q[5];
# cx q[0],q[5];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(5.207673570915423) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(-pi) q[0];
# rx(pi/2) q[0];
# rz(5.196691783976286) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# cx q[0],q[1];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(4.303977390157543) q[0];
# rx(pi/2) q[0];
# rz(5*pi/2) q[0];
# rz(-0.37434256554384593) q[1];
# rx(pi/2) q[1];
# rz(4.557424655397022) q[1];
# rx(pi/2) q[1];
# rz(9.050435395225534) q[1];
# cx q[0],q[1];
# rz(pi/2) q[0];
# rx(pi/2) q[0];
# rz(3.2022438568316236) q[0];
# rx(pi/2) q[0];
# rz(3*pi) q[0];
# rz(2.0057018099940827) q[1];
# rx(pi/2) q[1];
# rz(5.0820281579160325) q[1];
# rx(pi/2) q[1];
# rz(6.449475399405039) q[1];
# cx q[0],q[1];
# rz(-pi/2) q[0];
# rx(pi/2) q[0];
# rz(6.169204705550139) q[0];
# rx(pi/2) q[0];
# rz(2*pi) q[0];
# rz(pi/2) q[1];
# rx(pi/2) q[1];
# rz(3.376553887980903) q[1];
# rx(pi/2) q[1];
# rz(2*pi) q[1];
# rz(-pi/2) q[5];
# rx(pi/2) q[5];
# rz(5.253452419759343) q[5];
# rx(pi/2) q[5];
# rz(3*pi) q[5];
# rz(1.2517589579904493) q[5];
# rx(pi/2) q[5];
# rz(4.460591033893967) q[5];
# rx(pi/2) q[5];
# rz(8.778561053659796) q[5];
# cx q[2],q[5];
# rz(pi/2) q[2];
# rx(pi/2) q[2];
# rz(5.327007076948998) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(2.4876432817334653) q[5];
# rx(pi/2) q[5];
# rz(4.540376359724165) q[5];
# rx(pi/2) q[5];
# rz(8.199917756480255) q[5];
# cx q[2],q[5];
# rz(0) q[2];
# rx(pi/2) q[2];
# rz(4.068323238500186) q[2];
# rx(pi/2) q[2];
# rz(2*pi) q[2];
# rz(2.605594240608565) q[5];
# rx(pi/2) q[5];
# rz(3.838217143814657) q[5];
# rx(pi/2) q[5];
# rz(6.942143881228093) q[5];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(6.0711278239820405) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(6.028577218079227) q[9];
# rx(pi/2) q[9];
# rz(7*pi/2) q[9];
# cx q[9],q[4];
# rz(2.7125955397081754) q[4];
# rx(pi/2) q[4];
# rz(4.454120780042943) q[4];
# rx(pi/2) q[4];
# rz(8.252990046442621) q[4];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(5.1115278424870505) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[4];
# rz(-3.0323280531622214) q[4];
# rx(pi/2) q[4];
# rz(4.962302576394289) q[4];
# rx(pi/2) q[4];
# rz(9.842263994260051) q[4];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(4.784378416705241) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# cx q[4],q[7];
# rz(-pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.213696796572634) q[4];
# rx(pi/2) q[4];
# rz(5*pi/2) q[4];
# rz(-0.37434256554384593) q[7];
# rx(pi/2) q[7];
# rz(4.557424655397022) q[7];
# rx(pi/2) q[7];
# rz(9.050435395225534) q[7];
# cx q[4],q[7];
# rz(pi/2) q[4];
# rx(pi/2) q[4];
# rz(4.122917924727806) q[4];
# rx(pi/2) q[4];
# rz(3*pi) q[4];
# rz(2.0057018099940827) q[7];
# rx(pi/2) q[7];
# rz(5.0820281579160325) q[7];
# rx(pi/2) q[7];
# rz(6.449475399405039) q[7];
# cx q[4],q[7];
# rz(-pi) q[4];
# rx(pi/2) q[4];
# rz(5.7618592640274695) q[4];
# rx(pi/2) q[4];
# rz(2*pi) q[4];
# rz(-2.290140708880468) q[7];
# rx(pi/2) q[7];
# rz(4.401444265397123) q[7];
# rx(pi/2) q[7];
# rz(11.257413063868547) q[7];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(4.441516398786234) q[9];
# rx(pi/2) q[9];
# rz(3*pi) q[9];
# rz(-pi) q[9];
# rx(pi/2) q[9];
# rz(5.7431042646911195) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[8];
# rz(-0.37434256554384593) q[8];
# rx(pi/2) q[8];
# rz(4.557424655397022) q[8];
# rx(pi/2) q[8];
# rz(9.050435395225534) q[8];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.7030760597081063) q[9];
# rx(pi/2) q[9];
# rz(5*pi/2) q[9];
# cx q[9],q[8];
# rz(2.0057018099940827) q[8];
# rx(pi/2) q[8];
# rz(5.0820281579160325) q[8];
# rx(pi/2) q[8];
# rz(6.449475399405039) q[8];
# rz(-pi/2) q[9];
# rx(pi/2) q[9];
# rz(3.249844222483228) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
# cx q[9],q[8];
# rz(-pi/2) q[8];
# rx(pi/2) q[8];
# rz(5.192589661112418) q[8];
# rx(pi/2) q[8];
# rz(3*pi) q[8];
# rz(pi/2) q[9];
# rx(pi/2) q[9];
# rz(5.531092481067212) q[9];
# rx(pi/2) q[9];
# rz(2*pi) q[9];
